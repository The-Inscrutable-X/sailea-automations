# %%
import smtplib
from email.mime.text import MIMEText
import csv

# Gmail account credentials (replace with your own)
gmail_user = 'your_gmail_address@gmail.com'
gmail_password = 'your_gmail_password'

# CSV file path (replace with your CSV file path)
csv_file = 'output_staff_records.csv'

def send_email(recipient, subject, body):
    msg = MIMEText(body)
    msg['From'] = gmail_user
    msg['To'] = recipient
    msg['Subject'] = subject

    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.starttls()
    server.login(gmail_user, gmail_password)
    server.sendmail(gmail_user, recipient, msg.as_string())
    server.quit()

def main():
    with open(csv_file, 'r') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            recipient_prefix = row[4] 
            recipient_firstname = row[5] 
            recipient_lastname = row[7] 
            recipient_email = row[9] 
            subject = f"Personalized Subject for {recipient_email}"
            body = f"Hello {recipient_prefix}{recipient_firstname}{recipient_lastname},\n\nThis is a personalized email."
            print(body)
            # send_email(recipient_email, subject, body)

if __name__ == '__main__':
    main()
# Out:
# Name Prefix Last Name
# Mr Higgs
#  Rodrigues
#  Criss
#  Bradshaw
# Mrs Morris
# Ms Kreb
# Mrs Hoke
#  Russell
# Mr Burrows
# Mrs Lovell
#  Foster
#  Shoupe
#  Spencer
# Mrs Cornelius
# Mrs Cofield
# Mrs White
# Ms McDowell
# Ms Aiken
#  Scott-Gaddy
# Mr Cheek
# Mrs Townley
# Mrs Shuping
#  Ritter
#  Adams
# Dr Nabil
# Ms Drum
#  Farris
# Mrs Overton
# Ms Bailey
# Dr Jones
# Mrs Propst
#  Cornwell
# Mr Palozzi
# Ms Milliken
# Mrs Carter
# Ms Terregino
#  Berg
# Mrs Hayes
# Dr Robertson
# Ms White
# Mrs Palmer
# Mrs Branch
# Ms Frazier
# Mrs Little
# Mrs Watson
# Ms Davis
# Ms Davis
# Ms Bembry
#  West
# Mrs Wheeler
#  Williamson
# Ms Phillips
#  Ingram
# Mr Spence
#  Hinkle
# Mrs Cassell
# Mr Harris
#  Oldham
#  Howell
#  Cook
#  Campbell
#  Norris
# Ms Joell
# Mr Hart
#  McDonald
#  Suarez
#  Martin-Mack
#  Wood
# Mrs Place
#  South
# Mrs Williams
# Mrs Huffstetler
# Mrs Stallings
#  Williams
# Mrs Leary
# Mrs Sawyer
# Ms Cooper
# Ms Yager
#  Grissom-Young
# Mrs Wilkes
# Ms Ward
# ...
